# %%
import pandas as pd

# %%
house_df = pd.read_csv("../cleaned_data/PD43+_House_processed.csv")
print(house_df)
# Out:
#      year                         district                         name sex  \
# 0    2017                    1st Berkshire         John P. Barrett, III   m
# 1    2017                        3rd Essex             Andres X. Vargas   m
# 2    2016                   1st Barnstable            Timothy R. Whelan   m
# 3    2016                   2nd Barnstable      William L. Crocker, Jr.   m
# 4    2016                   3rd Barnstable              David T. Vieira   m
# 5    2016                   4th Barnstable               Sarah K. Peake   f
# 6    2016                   5th Barnstable                   Randy Hunt   m
# 7    2016  Barnstable, Dukes and Nantucket           Dylan A. Fernandes   m
# 8    2016                    1st Berkshire          Gailanne M. Cariddi   f
# 9    2016                    2nd Berkshire                 Paul W. Mark   m
# 10   2016                    3rd Berkshire        Tricia Farley-Bouvier   f
# ...

# %%
for i in range(2010, 2017):
    house_df[house_df['year'].isin([i])].to_csv("../cleaned_data/pd43/pd43_data_house_districts_" + str(i) + ".csv")

# %%
senate_df = pd.read_csv("../cleaned_data/PD43+_Senate_processed.csv", encoding = "ISO-8859-1")
print(senate_df)
# Out:
#      year                                    district  \
# 0    2017                         Bristol and Norfolk
# 1    2017                               4th Middlesex
# 2    2016           Berkshire, Hampshire and Franklin
# 3    2016                         Bristol and Norfolk
# 4    2016                    1st Bristol and Plymouth
# 5    2016                    2nd Bristol and Plymouth
# 6    2016                            Cape and Islands
# 7    2016                                   1st Essex
# 8    2016                                   2nd Essex
# 9    2016                                   3rd Essex
# 10   2016                     1st Essex and Middlesex
# 11   2016                     2nd Essex and Middlesex
# 12   2016                                     Hampden
# 13   2016                   1st Hampden and Hampshire
# 14   2016                   2nd Hampden and Hampshire
# 15   2016           Hampshire, Franklin and Worcester
# ...

# %%
for i in range(2010, 2017):
    senate_df[senate_df['year'].isin([i])].to_csv("../cleaned_data/pd43/pd43_data_senate_districts_" + str(i) + ".csv")
